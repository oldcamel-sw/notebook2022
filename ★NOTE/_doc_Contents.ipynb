# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#python" data-toc-modified-id="python-1">python</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Markdown" data-toc-modified-id="Markdown-1.0.1">Markdown</a></span></li><li><span><a href="#List,-Dictionary,-Tuple,-Set" data-toc-modified-id="List,-Dictionary,-Tuple,-Set-1.0.2">List, Dictionary, Tuple, Set</a></span></li><li><span><a href="#mutable-vs-immutable" data-toc-modified-id="mutable-vs-immutable-1.0.3">mutable vs immutable</a></span></li><li><span><a href="#shallow-copy-vs-deep-copy" data-toc-modified-id="shallow-copy-vs-deep-copy-1.0.4">shallow copy vs deep copy</a></span></li><li><span><a href="#for,-if,-while" data-toc-modified-id="for,-if,-while-1.0.5">for, if, while</a></span></li><li><span><a href="#variable-length-argument" data-toc-modified-id="variable-length-argument-1.0.6">variable length argument</a></span></li><li><span><a href="#Lambda-함수-(sort-key,-map,-apply)" data-toc-modified-id="Lambda-함수-(sort-key,-map,-apply)-1.0.7">Lambda 함수 (sort key, map, apply)</a></span></li><li><span><a href="#class,-instance,-method" data-toc-modified-id="class,-instance,-method-1.0.8">class, instance, method</a></span><ul class="toc-item"><li><span><a href="#instance-method,-class-method,-static-method" data-toc-modified-id="instance-method,-class-method,-static-method-1.0.8.1">instance method, class method, static method</a></span></li></ul></li><li><span><a href="#정규표현식" data-toc-modified-id="정규표현식-1.0.9">정규표현식</a></span></li><li><span><a href="#strings---split,-strip,-formatting" data-toc-modified-id="strings---split,-strip,-formatting-1.0.10">strings - split, strip, formatting</a></span></li><li><span><a href="#lexical-closures" data-toc-modified-id="lexical-closures-1.0.11">lexical closures</a></span></li><li><span><a href="#decorator" data-toc-modified-id="decorator-1.0.12">decorator</a></span></li><li><span><a href="#iterator,-generator" data-toc-modified-id="iterator,-generator-1.0.13">iterator, generator</a></span></li><li><span><a href="#Exercise" data-toc-modified-id="Exercise-1.0.14">Exercise</a></span></li></ul></li></ul></li><li><span><a href="#pandas,-numpy" data-toc-modified-id="pandas,-numpy-2">pandas, numpy</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#np-arrays" data-toc-modified-id="np-arrays-2.0.1">np arrays</a></span></li><li><span><a href="#ndarray-indexing" data-toc-modified-id="ndarray-indexing-2.0.2">ndarray indexing</a></span></li><li><span><a href="#ndarray-sorting" data-toc-modified-id="ndarray-sorting-2.0.3">ndarray sorting</a></span></li><li><span><a href="#np.random" data-toc-modified-id="np.random-2.0.4">np.random</a></span></li><li><span><a href="#np-operator" data-toc-modified-id="np-operator-2.0.5">np operator</a></span></li><li><span><a href="#np-linalg" data-toc-modified-id="np-linalg-2.0.6">np linalg</a></span></li><li><span><a href="#pd-series" data-toc-modified-id="pd-series-2.0.7">pd series</a></span></li><li><span><a href="#pd-descriptive" data-toc-modified-id="pd-descriptive-2.0.8">pd descriptive</a></span></li><li><span><a href="#pd-dataframe" data-toc-modified-id="pd-dataframe-2.0.9">pd dataframe</a></span></li><li><span><a href="#df-생성하기는-빼기-(or-아래랑-합치기)" data-toc-modified-id="df-생성하기는-빼기-(or-아래랑-합치기)-2.0.10">df 생성하기는 빼기 (or 아래랑 합치기)</a></span></li><li><span><a href="#df---ndarray---list---dict-relationship" data-toc-modified-id="df---ndarray---list---dict-relationship-2.0.11">df - ndarray - list - dict relationship</a></span></li><li><span><a href="#pd-handling-datatype" data-toc-modified-id="pd-handling-datatype-2.0.12">pd handling datatype</a></span></li><li><span><a href="#groupby---/-index-이용한-gruopby" data-toc-modified-id="groupby---/-index-이용한-gruopby-2.0.13">groupby   / index 이용한 gruopby</a></span></li><li><span><a href="#aggregate-function" data-toc-modified-id="aggregate-function-2.0.14">aggregate function</a></span></li><li><span><a href="#transform-function" data-toc-modified-id="transform-function-2.0.15">transform function</a></span></li><li><span><a href="#pivot-and-pivot-table" data-toc-modified-id="pivot-and-pivot-table-2.0.16">pivot and pivot table</a></span></li><li><span><a href="#df-concat,-merge,-join" data-toc-modified-id="df-concat,-merge,-join-2.0.17">df concat, merge, join</a></span></li><li><span><a href="#pd-where,-mask" data-toc-modified-id="pd-where,-mask-2.0.18">pd where, mask</a></span></li><li><span><a href="#pd-filter,-regex" data-toc-modified-id="pd-filter,-regex-2.0.19">pd filter, regex</a></span></li><li><span><a href="#examples" data-toc-modified-id="examples-2.0.20">examples</a></span></li></ul></li></ul></li><li><span><a href="#matplotlib,-seaborn" data-toc-modified-id="matplotlib,-seaborn-3">matplotlib, seaborn</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#기본그래프" data-toc-modified-id="기본그래프-3.0.1">기본그래프</a></span></li><li><span><a href="#그래프-주석-추가" data-toc-modified-id="그래프-주석-추가-3.0.2">그래프 주석 추가</a></span></li><li><span><a href="#subplot" data-toc-modified-id="subplot-3.0.3">subplot</a></span></li><li><span><a href="#histogram" data-toc-modified-id="histogram-3.0.4">histogram</a></span></li></ul></li><li><span><a href="#Examplars" data-toc-modified-id="Examplars-3.1">Examplars</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#relationship" data-toc-modified-id="relationship-3.1.0.1">relationship</a></span></li><li><span><a href="#data-over-time" data-toc-modified-id="data-over-time-3.1.0.2">data over time</a></span></li><li><span><a href="#ranking" data-toc-modified-id="ranking-3.1.0.3">ranking</a></span></li><li><span><a href="#distribution" data-toc-modified-id="distribution-3.1.0.4">distribution</a></span></li><li><span><a href="#comparisons" data-toc-modified-id="comparisons-3.1.0.5">comparisons</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#추론통계" data-toc-modified-id="추론통계-4">추론통계</a></span><ul class="toc-item"><li><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#표준오차-개념-이해" data-toc-modified-id="표준오차-개념-이해-4.0.0.1">표준오차 개념 이해</a></span></li><li><span><a href="#표집분포(Sampling-distribution)" data-toc-modified-id="표집분포(Sampling-distribution)-4.0.0.2">표집분포(Sampling distribution)</a></span></li></ul></li><li><span><a href="#추정과-검정" data-toc-modified-id="추정과-검정-4.0.1">추정과 검정</a></span><ul class="toc-item"><li><span><a href="#점추정-/-신뢰구간추정" data-toc-modified-id="점추정-/-신뢰구간추정-4.0.1.1">점추정 / 신뢰구간추정</a></span></li></ul></li><li><span><a href="#모수검정을-중심으로.." data-toc-modified-id="모수검정을-중심으로..-4.0.2">모수검정을 중심으로..</a></span><ul class="toc-item"><li><span><a href="#z-test-&amp;-t-test" data-toc-modified-id="z-test-&amp;-t-test-4.0.2.1">z-test &amp; t-test</a></span></li><li><span><a href="#proportion-test" data-toc-modified-id="proportion-test-4.0.2.2">proportion test</a></span></li><li><span><a href="#카이제곱검정" data-toc-modified-id="카이제곱검정-4.0.2.3">카이제곱검정</a></span></li></ul></li></ul></li><li><span><a href="#동일성-검정-/-독립성-검정-/-적합도-검정" data-toc-modified-id="동일성-검정-/-독립성-검정-/-적합도-검정-4.1">동일성 검정 / 독립성 검정 / 적합도 검정</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#ANOVA" data-toc-modified-id="ANOVA-4.1.0.1">ANOVA</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#Machine-Learning" data-toc-modified-id="Machine-Learning-5">Machine Learning</a></span><ul class="toc-item"><li><span><a href="#General" data-toc-modified-id="General-5.1">General</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Null-값-처리" data-toc-modified-id="Null-값-처리-5.1.0.1">Null 값 처리</a></span></li><li><span><a href="#Feature-Engineering-개요" data-toc-modified-id="Feature-Engineering-개요-5.1.0.2">Feature Engineering 개요</a></span></li><li><span><a href="#Feature-Selection" data-toc-modified-id="Feature-Selection-5.1.0.3">Feature Selection</a></span></li><li><span><a href="#PIPELINE-내용-추가" data-toc-modified-id="PIPELINE-내용-추가-5.1.0.4"><strong>PIPELINE</strong> 내용 추가</a></span></li><li><span><a href="#교차검증-(분류모델-/-회귀모델-모두-사용-가능하다)" data-toc-modified-id="교차검증-(분류모델-/-회귀모델-모두-사용-가능하다)-5.1.0.5">교차검증 (분류모델 / 회귀모델 모두 사용 가능하다)</a></span></li><li><span><a href="#Class-Imbalance" data-toc-modified-id="Class-Imbalance-5.1.0.6">Class Imbalance</a></span></li></ul></li></ul></li><li><span><a href="#Supervised" data-toc-modified-id="Supervised-5.2">Supervised</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Linear-Regression-and-Multiple-Linear-Regression-(회귀)" data-toc-modified-id="Linear-Regression-and-Multiple-Linear-Regression-(회귀)-5.2.0.1">Linear Regression and Multiple Linear Regression (회귀)</a></span></li><li><span><a href="#Logistic-Regression-(분류)" data-toc-modified-id="Logistic-Regression-(분류)-5.2.0.2">Logistic Regression (분류)</a></span></li><li><span><a href="#Gaussian-Naive-Bayes-(분류/회귀)" data-toc-modified-id="Gaussian-Naive-Bayes-(분류/회귀)-5.2.0.3">Gaussian Naive Bayes (분류/회귀)</a></span></li><li><span><a href="#SVM-(회귀)--(#Raschka_1)" data-toc-modified-id="SVM-(회귀)--(#Raschka_1)-5.2.0.4">SVM (회귀)  (#Raschka_1)</a></span></li><li><span><a href="#KNN-(분류)-(#Raschka_1)" data-toc-modified-id="KNN-(분류)-(#Raschka_1)-5.2.0.5">KNN (분류) (#Raschka_1)</a></span></li><li><span><a href="#Decision-Tree-(분류/회귀)" data-toc-modified-id="Decision-Tree-(분류/회귀)-5.2.0.6">Decision Tree (분류/회귀)</a></span></li><li><span><a href="#Neural-Network" data-toc-modified-id="Neural-Network-5.2.0.7">Neural Network</a></span></li></ul></li></ul></li><li><span><a href="#Unsupervised" data-toc-modified-id="Unsupervised-5.3">Unsupervised</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#K-means-(#note_11)" data-toc-modified-id="K-means-(#note_11)-5.3.0.1">K-means (#note_11)</a></span></li><li><span><a href="#Hierarchical-clutering-(#note_11)" data-toc-modified-id="Hierarchical-clutering-(#note_11)-5.3.0.2">Hierarchical clutering (#note_11)</a></span></li><li><span><a href="#DBSCAN-(#note_11)" data-toc-modified-id="DBSCAN-(#note_11)-5.3.0.3">DBSCAN (#note_11)</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#Ensemble" data-toc-modified-id="Ensemble-6">Ensemble</a></span><ul class="toc-item"><li><span><a href="#Pipeline" data-toc-modified-id="Pipeline-6.1">Pipeline</a></span></li></ul></li><li><span><a href="#Deep-Learning" data-toc-modified-id="Deep-Learning-7">Deep Learning</a></span></li></ul></div>

# %% [markdown]
# # python
#
# ### Markdown
#
# ### List, Dictionary, Tuple, Set
# - dict.values, dict.keys, dict.items
# - enumerate
# - append와 extend의 차이
# - set와
#
#
# ### mutable vs immutable
#
#
# ### shallow copy vs deep copy
#
#
#
# ### for, if, while
#
#
# ### variable length argument
# - \*args, \**kwargs
#
#
# ### Lambda 함수 (sort key, map, apply)
#
#
# ### class, instance, method
#
# #### instance method, class method, static method
#
# ### 정규표현식
#
#
# ### strings - split, strip, formatting
#
#
# ### lexical closures
#
#
# ### decorator
#
# ### iterator, generator
#
#
# ### Exercise
# - 복소수 클래스 만들기
# - team code review
# - 함수 과제
# - 모방 set oop과제
# -

# %% [markdown]
# # pandas, numpy
#
# ### np arrays
# - np.array, np.arange, np.ones, np.linspace, etc.
#
# ### ndarray indexing
#
#
# ### ndarray sorting
#
#
# ### np.random
#
#
# ### np operator
#
#
# ### np linalg
#
#
# ### pd series
#
#
#
# ### pd descriptive
# - df.shape,
# - df.describe, .info, .corr() etc.
#
#
# ### pd dataframe
# - .columns, .index, .index.values
# - .query
# - indexing, slicing df[:10], df[['columns', 'columns2']]
# - .iloc, .loc
#
# ### df 생성하기는 빼기 (or 아래랑 합치기)
#
# ### df - ndarray - list - dict relationship
#
#
#
#
# ### pd handling datatype
#
#
# ### groupby   / index 이용한 gruopby
#
# ### aggregate function
#
# ### transform function
#
# ### pivot and pivot table
#
#
# ### df concat, merge, join
#
# ### pd where, mask
#
# ### pd filter, regex
#
#
# ### examples
# - skewness가 큰 데이터에 log 취하기
# - 가위바위보게임, 숫자맞추기 게임, 커피자판기
# - 연락처관리 프로그램
# - 포스코 빅데이터 조작 실습

# %% [markdown]
# # matplotlib, seaborn
#
# ### 기본그래프
#
# ### 그래프 주석 추가
#
# ### subplot
#
#
# ### histogram
#
#
# ## Examplars
# - plot.pit, sns.countplot
# - plot.bar
# - sns.factorplot
# - sns.kdeplot, plot(kde)
# - sns.violinplot
# - sns.distplot
# - sns.heatmap
# - sns.barplot
# - sns.facetgrid and map
# - two y-axis
# - plot decision grid
# - plot learning curve

# %% [markdown]
# #### relationship
# - scatter plot
# - marginal histogram
# - pair plot
# - heatmap
#
# #### data over time
# - line chart
# - area chart
# - stacked area chart
# - area chart unstacked
#
# #### ranking
# - vertical bar chart
# - horizontal bar chart
# - multi-set bar chart
# - stack bar chart
# - lollipop chart
#
# #### distribution
# - histogram
# - density plot
# - box plot
# - strip plot
# - violin plot
# - population pyramid
#
# #### comparisons
# - bubble chart
# - bullet chart
# - pie chart
# - net pie chart
# - donut chart
# - tree map
# - diverging bar
# - choropleth map
# - bubble map

# %% [markdown]
# # 추론통계
#
# - 분포 roadmap
#
# - 분포별 확률 계산 stats library 실습
#     - 정규분포
#     - t분포
#     - 카이제곱분포
#     - f분포
#     - 와이블분포
#     - 이항분포
#     - 포아송분포
#
#
# #### 표준오차 개념 이해
#
#
# #### 표집분포(Sampling distribution)
# - 표본평균의 분포
#     - 모집단이 정규분포이거나, 표본크기가 30 이상이거나, 표본에 대한 정규성 검정이 채택되었을 때,
#     - 모분산을 알고 있으면 표본평균의 분포를 "정규분포"로 가정하고,
#     - 모분산을 모르면 표본평균의 분포를 "t 분포"로 가정한다.
#
#     - 이때 표본평균 분포의 평균(기대값)은 모평균과 같고,
#     - 분포의 분산은 모분산(혹은 표본분산)을 n으로 나눈 것과 같고,
#     - 분포의 표준편차를 '표준오차'라고 한다.
#
# - 표본비율의 분포
#     - 표본비율의 분포는 이항분포를 따르는데, 이항분포 B(n, p)는 n이 충분히 크면 근사적으로 정규분포 N(np, npq)를 따른다.
#
#     - 표본비율 분포의 평균은 모비율과 같고,
#     - 표본비율 분포의 분산은
#
# - 표본분산의 분포
#     - 모집단이 정규분포를 따를 때, 표본분산의 분포는 카이제곱분포를 따른다.
#
#
# - 표본분산비율의 분포
#     - 정규분포를 이루는 모집단으로부터 추출된 두 독립적인 표본간 표본분산비율의 분포는 F분포를 따른다.
#
#
# ### 추정과 검정
# - 추정 / 검정의 개념 차이
# - 추정의 종류 (점추정 / 신뢰구간추정)
# - 검정의 종류 (비모수 / 모수)
#
# #### 점추정 / 신뢰구간추정
# - 모평균 점추정 (표본평균)
# - 모평균 신뢰구간 추정 (z통계량, t통계량)
# - 모분산 점추정 (표본분산)
# - 모분산 신뢰구간 추정 (카이제곱통계량)
# - 모비율 점추정 (표본비율)
# - 모비율 신뢰구간 추정 (z통계량)
#
#
# ### 모수검정을 중심으로..
# - 검정 roadmap / decision tree
# - 몇몇 검정 기법의 가정
#     - 정규성 검정 shapiro
#     - 등분산성 검정 Bartlett, Levene
#
# #### z-test & t-test
# - '평균'에 통계적으로 유의한 차이가 있는가?
# - t-test의 종류
#     - one sample t test
#     - two sample t test
#     - paired t test
# - t-test의 가정
#
# #### proportion test
# - '비율'에 통계적으로 유의한 차이가 있는가?
# - 종류
#     - 1 proportion test
#     - 2 proportion test
# - proportion test의 가정
#
# #### 카이제곱검정
# - 동일성 검정 / 독립성 검정 / 적합도 검정
#     -
# - 카이제곱검정의 가정
#
# #### ANOVA
#
# - ANOVA의 가정

# %% [markdown]
# # Machine Learning

# %% [markdown]
# ## General
#
# #### Null 값 처리
# - fillna
# - SimpleImputer (#Raschka_2)
#
# #### Feature Engineering 개요
# - 각각의 역할과 의미 (scaling, labeling, selection, extraction)
# - 어떤 모델에서 중요한지?
# - 어떤 효과를 갖는지?
#
# ##### Feature Scaling - 정규화 표준화
# - standardscaler
# - minmax scaler
#
# ##### Feature Labeling
# - LabelEncoder
# - mapping
# - OneHotEncoding
# - string 처리: 앞글자 하나를 레이블로
# - numeric to category: age를 category화하는 함수를 apply하기
# - preprocessing pipeline 예시
#
# ##### Feature Regularization
# - 규제 Regularization L1, L2
# - Ridge, Lasso, ElasticNet
#
#
# #### Feature Selection
# - 순차특성선택 알고리즘 SBS
# - Forward, Backward, Stepwise (#doc_models)
# - VIF를 이용한 변수 제거 (#doc_models)
#
# ##### Feature Extraction
# - PCA (#doc_models) (#Raschka_2)
# - LDA (#Raschka_2)
# - Kernel PCA (#Raschka_2)
#
# #### **PIPELINE** 내용 추가
#
# #### 교차검증 (분류모델 / 회귀모델 모두 사용 가능하다)
# - Kfold (#inflearn_ML)  (#Raschka_3)
#     - 학습곡선 시각화 (#Raschka_3)
# - cross_val_score, gridsearchCV (#inflearn_ML)
# - scoring='accuracy'말고 회귀모델 대상으로 어떻게 사용하는지 확인
#
# #### Class Imbalance
# - Resample (#Raschka_3)
# - undersampling, oversampling (#note_12-imbalance)
# - SMOTE (#note_12-imbalance)

# %% [markdown]
# ## Supervised
# ***train_test_split까지 완료해놓고 data return하는 함수 정의하자***
#
# #### Linear Regression and Multiple Linear Regression (회귀)
# - 모델링, model performance 확인 (#doc_models)
#     - 상관분석 (correlation) 수식
# - (#Raschka_4)
# - 다중공선성 진단법 (vif) (#doc_models)
#     - 해결법은 general 확인
# - 적합성 진단 - 잔차분석 (#doc_models)
# - ridge, lasso (# doc_models)
#
#
#
# #### Logistic Regression (분류)
# - 파이썬으로 경사하강법 적용 로지스틱 분류기 구현 (#Raschka_1)
# - 모델링, model performance 확인 (#doc_models)
# - feature selection 함수 만들기(#doc_models)
#
# #### Gaussian Naive Bayes (분류/회귀)
#
#
# #### SVM (회귀)  (#Raschka_1)
# - SVM
# - 슬랙 변수 SVM
# - Kernel SVM
#
#
# #### KNN (분류) (#Raschka_1)
#
#
# #### Decision Tree (분류/회귀)
# - 모델링, 시각화 (#note_9-2) (#inflearn ML2) (#Raschka_1)
#     - Feature importance 확인 (#inflearn ML2)
#     - Decision boundary 시각화하기 (#inflearn ML2)
# - 하이퍼파라미터 (#note_9-2)
# - decision regression tree 모델 briefly (#note_9-2)
#
#
# #### Neural Network
# - 퍼셉트론 구현 (#Raschka_1)
#     - decision boundary 시각화하기 (#Raschka_1)
# - 경사하강법 적용 적응형 선형 뉴런(AdalineGD) 구현 (#Raschka_1)
# - 확률적 경사하강법 적용 적응형 선형 뉴런(AdalineSGD) 구현 (#Raschka_1)

# %% [markdown]
# ## Unsupervised
#
# #### K-means (#note_11)
#
# #### Hierarchical clutering (#note_11)
#
# #### DBSCAN (#note_11)

# %% [markdown]
# # Ensemble
#
# 직접 다수결 투표 분류기 구현 (#Raschka_3)
#
# Bagging
#
# Boosting
# - XGBoost
# - Gradient Boosting
# - LightGBM
#
# Pipeline
# -
#
# 랜덤포레스트
# - 특성중요도  (#Raschka_2)
#
#
# SHAP value

# %% [markdown]
# # Deep Learning
#
# Deep Neural Network from Scratch
#
# CNN
#
# GAN
